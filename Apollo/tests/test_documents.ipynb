# %%
from pathlib import Path
import sys
import pandas as pd

__PATH__ = Path("../..").absolute().resolve()
print("ADDING TO PATH:", str(__PATH__), " exists: ", Path(__PATH__).exists())
sys.path.append(str(__PATH__))


from Conversation.converse.documents import PDF, DocumentExtract
from io import BytesIO

with open("../openai_key", 'r') as f:
    GPT_KEY = f.read()

sample_pdf = r"C:\Users\nagen\Desktop\gpt\sample.pdf"
with open(sample_pdf, 'rb') as f:
    _io = BytesIO(f.read())
    _io.seek(0)
    pdf = PDF(_io)
# Out:
# ADDING TO PATH: C:\Users\nagen\Desktop\gpt\project_apollo  exists:  True

# %%
docextract = DocumentExtract(pdf, GPT_KEY, EXTRACT_USER_RELATED_INFO, extract_user_health_information_entry)
results = docextract.extract()

# %%
df = pd.concat([x[-1][-1]["extract_user_health_information_entry"][0] for x in results if "extract_user_health_information_entry" in x[-1][-1]]).reset_index(drop=True)
# df[df['parameter_value'] == "Not provided"]
df


# results[-1][-1][-1]["extract_user_health_information_entry"][0] # XD
# Out:
#                      i_parameter_label parameter_type  \
# 0                       Fasting Status      Lifestyle
# 1                    Cholesterol Total         Report
# 2                      HDL Cholesterol         Report
# 3                        Triglycerides         Report
# 4                      LDL Cholesterol         Report
# ..                                 ...            ...
# 65                  Leukocyte Esterase         Report
# 66                            Bacteria         Report
# 67              HbA1c (Hemoglobin A1C)         Report
# 68     PSA (Prostate-specific antigen)         Report
# 69  Patient Service Center appointment      Lifestyle
#
#                                parameter_value
# 0                                          Yes
# 1                                    248 mg/dL
# 2                                     60 mg/dL
# 3                                    126 mg/dL
# 4                             163 mg/dL (high)
# ..                                         ...
# 65                                Not provided
# 66                                Not provided
# 67                                          8%
# 68                                   183 mg/dL
# 69  Suggested to schedule at Quest Diagnostics
#
# [70 rows x 3 columns]

# %%
from pathlib import Path
import pandas as pd
from io import BytesIO
import requests

import sys
__PATH__ = Path("..").absolute().resolve()
print("ADDING TO PATH:", str(__PATH__), " exists: ", Path(__PATH__).exists())
sys.path.append(str(__PATH__))

from Conversation.converse.documents import PDF, DocumentExtract

sample_pdf = r"C:\Users\nagen\Desktop\gpt\sample.pdf"
with open(sample_pdf, 'rb') as f:
    # _io = BytesIO(f.read())
    # _io.seek(0)
    # pdf = PDF(_io)
    # _io.seek(0)
    files = {'attachment': f}
# Out:
# ADDING TO PATH: C:\Users\nagen\Desktop\gpt\project_apollo\Apollo  exists:  True

# %%
sample_pdf = r"C:\Users\nagen\Desktop\gpt\sample.pdf"
with open(sample_pdf, 'rb') as f:
    # files = {'attachment': f}
    files = [('attachment', f)]
    
    url = "http://127.0.0.1:8000/conversation/test/"
    response = requests.post(
        url,
        files=files,
        headers={"Authorization": "Bearer gAAAAABmpr6XN-izDKPPtHLQNeUPBUkn5HbTXlEKUFhF4vDhEpwelmzkWL7FvmSvlbxXAG48SFdzEu61Zpd-_zvzfDAgegKM_StELDj7BhbYNnxQbbmA9Dqs4M9HlLYRkNcRsucHbVj0XuuNZpkboyysBG6R9lHyFGA76g8MlGD4_sIJEEaUezrjt6CRL8MQgyKf4Jbw3KyDKK2_vtNWg2EtaMQF2pr1Yx2kf5AlmichZRCiNUKKF327WjNJ8AroDUO-p6VikGjtZ4Cg3uf4zF1ejcXC2HvMFw=="},
        data = {}
    )
    print(response.status_code)
    print(response.content)
# Out:
# 500
# b'{"error":{"code":"Internal Server Error","message":"something went wrong"}}'

# %%
response.json()
# Out:
# {'id': '66a7995e6253577b152ed920',
#  'file_bytes': '...',
#  'document_preview_bytes': '...',
#  'document_type': 'pdf',
#  'number_pages': 21,
#  'discription': None,
#  'shared_globaly': False,
#  'shared_at': None,
#  'created_at': '2024-07-29T18:59:40.873418Z',
#  'session': '66a795a7daf17c3f8c8d41ee'}

# %%
len(pdf.pdf)

import base64

base64.b64encode(pdf.pdf.tobytes()).decode()
# Out:
# '...'
